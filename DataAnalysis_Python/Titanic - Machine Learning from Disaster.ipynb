# %% [markdown]
# Features of the dataset:
#
# - survival - Survival (0 = No; 1 = Yes)
# - class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - name - Name
# - sex - Sex
# - age - Age
# - sibsp - Number of Siblings/Spouses Aboard
# - parch - Number of Parents/Children Aboard
# - ticket - Ticket Number
# - fare - Passenger Fare
# - cabin - Cabin
# - embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
#
# Questions :
#
#
# 1. Display Top 5 Rows of The Dataset
# 2. Check the Last 3 Rows of The Dataset
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
# 5. Get Overall Statistics About The Dataframe
# 6. Data Filtering
# 7.Check Null Values In The Dataset
# 8. Drop the Column
# 9. Handle Missing Values
# 10. Categorical Data Encoding

# %%
#1. Display Top 5 Rows of The Dataset
import numpy as np
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 8E54-B253
#
#  Directory of C:\ExcelR\DataAnalysis_Python
#
# 02/26/2022  05:29 PM    <DIR>          .
# 02/26/2022  05:29 PM    <DIR>          ..
# 02/20/2022  11:24 AM    <DIR>          .ipynb_checkpoints
# 02/13/2022  04:58 PM         5,326,368 adult.csv
# 02/19/2022  08:30 PM           265,242 Data Analysis with Python Pandas_Adult income dataset.ipynb
# 02/12/2022  11:16 AM           119,190 Data Analysis With Python Pandas_E-Commerce Purchases Dataset.ipynb
# 02/17/2022  05:02 PM           121,735 Data Analysis With Python Pandas_SF City Employee Salary.ipynb
# 02/11/2022  11:40 PM            62,335 Data Analysis With Python Pandas-Warmup.ipynb
# 02/12/2022  11:17 AM        18,592,768 database.sqlite
# 02/11/2022  11:54 PM         2,745,852 Ecommerce Purchases
# 02/20/2022  11:58 AM           114,431 Financial Sample_20Feb.xlsx
# 02/19/2022  08:38 PM             3,258 gender_submission.csv
# ...

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#1. Display Top 5 Rows of The Dataset
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 2. Check the Last 3 Rows of The Dataset
data.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Find Shape of Our Dataset (Number of Rows & Number of Columns)
data.shape
# Out:
# (891, 12)

# %%
print("Number of Rows ",data.shape[0])
print("Number of Columns ", data.shape[1])
# Out:
# Number of Rows  891
# Number of Columns  12

# %%
# Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column 
# And Memory Requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Get Overall Statistics About The Dataframe
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
data["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#Data Filtering
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data["Age"]>30
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
data[data["Age"]>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data["Age"]>30] ["Name"]
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
#                              ...
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 881                                   Markun, Mr. Johann
# 885                 Rice, Mrs. William (Margaret Norton)
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 305, dtype: object

# %%
data["Survived"]==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
#Count number of people who survived
sum(data["Survived"]==1)
# Out:
# 342

# %%
len(data["Survived"]==1) # this will include both matching and not matching criteria
# Out:
# 891

# %%
#Check Null Values In The Dataset
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#To visualise we need seaborn and to plot we need matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
#Find percentage value of missing data
per_missing=data.isnull().sum() * 100 / len(data)

# %%
per_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
# Drop the Column
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.drop("Cabin",axis=1) #To drop the column, not rows
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#To reflect the drop of column use inplace parameter in drop
data.drop("Cabin",axis=1,inplace=True)

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
#Handle Missing Values
#replace the missing values with most frequent values.
data["Embarked"].mode() #for embark column most used value is S
# Out:
# 0    S
# dtype: object

# %%
data["Embarked"].fillna("S",inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
data["Age"].fillna(data["Age"].mean(),inplace=True)

# %%
data.isnull().sum() #to check if there are missing values
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#  Categorical Data Encoding, used for giving data to algorithms / models
data["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data["Gender"]=data["Sex"].map({"male":1,"female":0})

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked  Gender
# 0      0  A/5 21171   7.2500        S       1
# 1      0   PC 17599  71.2833        C       0

# %%
x=data["Sex"].map({"male":1,"female":0}) #instead of map, we can also use get_dummies method of pandas for enconding

# %%
data.insert(4,"Gender_New",x)

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name  Gender_New     Sex  \
# 0                            Braund, Mr. Owen Harris           1    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           0  female
# 2                             Heikkinen, Miss. Laina           0  female
#
#     Age  SibSp  Parch            Ticket     Fare Embarked  Gender
# 0  22.0      1      0         A/5 21171   7.2500        S       1
# 1  38.0      1      0          PC 17599  71.2833        C       0
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S       0

# %%
#if there are more than one catagorical column, it is better to use get_dummies method. like embarked as more than 2 values
data["Embarked"].nunique()
# Out:
# 3

# %%
data["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
print("Unique count in Sex Column ",data["Sex"].nunique(),"\nUnique count in Embarked Column ",data["Embarked"].nunique())
# Out:
# Unique count in Sex Column  2
# Unique count in Embarked Column  3

# %%
print("Unique values in Sex Column ",data["Sex"].unique(),"\nUnique values in Embarked Column ",data["Embarked"].unique())
# Out:
# Unique values in Sex Column  ['male' 'female']
# Unique values in Embarked Column  ['S' 'C' 'Q']

# %%
#as there can be more than 2 unique value in category based columns, we use get_dummies method
pd.get_dummies(data,columns=["Embarked"])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender_New     Sex  \
# 0                              Braund, Mr. Owen Harris           1    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           0  female
# 2                               Heikkinen, Miss. Laina           0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           0  female
# 4                             Allen, Mr. William Henry           1    male
# ..                                                 ...         ...     ...
# ...

# %%
#There are 3 additional columns created. using 2 column values we can predict the third column value, 
#if two are 0, 3 would be 1. so we can drop first column
pd.get_dummies(data,columns=["Embarked"],drop_first=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender_New     Sex  \
# 0                              Braund, Mr. Owen Harris           1    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           0  female
# 2                               Heikkinen, Miss. Laina           0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           0  female
# 4                             Allen, Mr. William Henry           1    male
# ..                                                 ...         ...     ...
# ...

# %% [markdown]
# ## What is Univariate Analysis?
# Dealing with one variable analysis like, age, sex, embarked, any one categorical column`b

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender_New', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# How Many People Survived And How Many Died?
data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(data["Survived"]) #count plot can be used for categorical column values only i.e. non-numerical values
# Out:
# C:\Users\svats21\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#How Many Passengers Were In First Class, Second Class, and Third Class?
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(data["Pclass"])
# Out:
# C:\Users\svats21\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
#Number of Male And Female Passengers

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(data["Sex"])
# Out:
# C:\Users\svats21\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#Use Age value for analysis as it is not discreet, but continous
#count plot cant be used, need to use histogram method from matplotlib to plan
data["Age"].value_counts() #there are more than 89 different values.
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: Age, Length: 89, dtype: int64

# %%
plt.hist(data["Age"])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#We can also use the box plot to get a beter analysis
sns.boxplot(data["Age"],orient="v")
# Out:
# C:\Users\svats21\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\svats21\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ## Bivariate Analysis

# %%
#Who Has Better Chance of Survival Male or Female?
sns.barplot(x="Sex",y="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
#Which Passenger Class Has Better Chance of Survival (First, Second, Or Third Class)? 
sns.barplot(x="Pclass",y="Survived",data=data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
#13. Feature Engineering
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender_New', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
data["Family_Size"]=data["SibSp"] + data["Parch"] + 1  #+1 To add himself

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  Gender_New   Sex  \
# 0            1         0       3  Braund, Mr. Owen Harris           1  male
#
#     Age  SibSp  Parch     Ticket  Fare Embarked  Gender  Family_Size
# 0  22.0      1      0  A/5 21171  7.25        S       1            2

# %%
#Now calculate the average fare for
data["Average_Fare"]=data["Fare"] / data["Family_Size"]

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  Gender_New   Sex  \
# 0            1         0       3  Braund, Mr. Owen Harris           1  male
#
#     Age  SibSp  Parch     Ticket  Fare Embarked  Gender  Family_Size  \
# 0  22.0      1      0  A/5 21171  7.25        S       1            2
#
#    Average_Fare
# 0         3.625
